# %% [markdown]
# # Model-fitting
#
# **Plan:**
#
# 1. Fit RSA models to data of Experiment 1:
#     1. For each language, fit RSA+distance and RSA+person
#     2. Given best fit of RSA+distance and RSA+person, do model-comparison (Bayes factors?) to see which model performs best
#     3. Given best fit (distance or person) see how well the simple version of that model (i.e. without RSA reasoning) would do to fit the data: Do model-comparison between simple and RSA version.
# 2. Pre-register model-fitting for Experiment 2, with parameter settings that were fit to the data of Experiment 1. Repeat steps B and C above.

# %% [markdown]
# ## Maximum likelihood estimation
#
# **Goal:** Try to find parameter settings that maximise the likelihood of the data.
# In order to do that, we first need to define a _likelihood function_.
#
# **Likelihood function, single parameter:**
#
# $$ \mathcal{L}(\theta | x_{1}, ..., x_{n}) = \prod_{i=1}^{n} f(x_{i} | \theta) $$
#
#
# where $\theta$ is the parameter setting.
#
# In our case however, we have two parameters that we want to fit simultaneously. Let's call them $\theta_{1}$ and $\theta_{2}$.
#
# **<span class="mark">Q: Likelihood function with two parameters??:</span>**
#
# $$ \mathcal{L}(\theta_{1}, \theta_{2} | x_{1}, ..., x_{n}) = \prod_{i=1}^{n} f(x_{i} | \theta_{1}, \theta_{2}) $$

# %% [markdown]
# ### Loading in the data:

# %%
import pandas as pd

data_exp_1_two_system = pd.read_csv('data/with_counts/TwoSystem.csv', index_col=0)  

data_exp_1_two_system
# Out:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 1                 1                  1  English     51    46      5  0.901961
# 2                 1                  1  Italian     51    51      0  1.000000
# 3                 1                  2  English     51    46      5  0.901961
# 4                 1                  2  Italian     51    51      0  1.000000
# 5                 1                  3  English     51    42      9  0.823529
# 6                 1                  3  Italian     51    50      1  0.980392
# 7                 1                  4  English     51    47      4  0.921569
# 8                 1                  4  Italian     51    50      1  0.980392
# 9                 2                  1  English     51    25     26  0.490196
# 10                2                  1  Italian     51    36     15  0.705882
# 11                2                  2  English     51    29     22  0.568627
# 12                2                  2  Italian     51    37     14  0.725490
# 13                2                  3  English     51    30     21  0.588235
# 14                2                  3  Italian     51    34     17  0.666667
# 15                2                  4  English     51    32     19  0.627451
# 16                2                  4  Italian     51    35     16  0.686275
# 17                3                  1  English     51     8     43  0.156863
# 18                3                  1  Italian     51     1     50  0.019608
# 19                3                  2  English     51     8     43  0.156863
# 20                3                  2  Italian     51     1     50  0.019608
# 21                3                  3  English     51    14     37  0.274510
# 22                3                  3  Italian     51     3     48  0.058824
# 23                3                  4  English     51    15     36  0.294118
# 24                3                  4  Italian     51     3     48  0.058824
# 25                4                  1  English     51    10     41  0.196078
# 26                4                  1  Italian     51     0     51  0.000000
# 27                4                  2  English     51     6     45  0.117647
# 28                4                  2  Italian     51     1     50  0.019608
# 29                4                  3  English     51     7     44  0.137255
# 30                4                  3  Italian     51     2     49  0.039216
# 31                4                  4  English     51    10     41  0.196078
# 32                4                  4  Italian     51     3     48  0.058824
#
#       Aquelp
# 1   0.098039
# 2   0.000000
# 3   0.098039
# 4   0.000000
# 5   0.176471
# 6   0.019608
# 7   0.078431
# 8   0.019608
# 9   0.509804
# 10  0.294118
# 11  0.431373
# 12  0.274510
# 13  0.411765
# 14  0.333333
# 15  0.372549
# 16  0.313725
# 17  0.843137
# 18  0.980392
# 19  0.843137
# 20  0.980392
# 21  0.725490
# 22  0.941176
# 23  0.705882
# 24  0.941176
# 25  0.803922
# 26  1.000000
# 27  0.882353
# 28  0.980392
# 29  0.862745
# 30  0.960784
# 31  0.803922
# 32  0.941176

# %%
data_exp_1_three_system = pd.read_csv('data/with_counts/ThreeSystem.csv', index_col=0)  

data_exp_1_three_system
# Out:
#     Object_Position  Listener_Position    Language  Total  este  ese  aquel  \
# 1                 1                  1  Portuguese     50    47    3      0
# 2                 1                  1     Spanish     50    50    0      0
# 3                 1                  2  Portuguese     50    48    1      1
# 4                 1                  2     Spanish     50    49    1      0
# 5                 1                  3  Portuguese     50    47    3      0
# 6                 1                  3     Spanish     50    49    1      0
# 7                 1                  4  Portuguese     50    48    2      0
# 8                 1                  4     Spanish     50    49    0      1
# 9                 2                  1  Portuguese     50    11   23     16
# 10                2                  1     Spanish     50     9   41      0
# 11                2                  2  Portuguese     50     9   40      1
# 12                2                  2     Spanish     50    16   34      0
# 13                2                  3  Portuguese     50    18   24      8
# 14                2                  3     Spanish     50    17   33      0
# 15                2                  4  Portuguese     50    21   15     14
# 16                2                  4     Spanish     50    15   34      1
# 17                3                  1  Portuguese     50     0    5     45
# 18                3                  1     Spanish     50     1   24     25
# 19                3                  2  Portuguese     50     0   17     33
# 20                3                  2     Spanish     50     0   40     10
# 21                3                  3  Portuguese     50     1   43      6
# 22                3                  3     Spanish     50     0   44      6
# 23                3                  4  Portuguese     50     2   35     13
# 24                3                  4     Spanish     50     0   41      9
# 25                4                  1  Portuguese     50     0    1     49
# 26                4                  1     Spanish     50     0    1     49
# 27                4                  2  Portuguese     50     0    2     48
# 28                4                  2     Spanish     50     0    3     47
# 29                4                  3  Portuguese     50     0   10     40
# 30                4                  3     Spanish     50     0   12     38
# 31                4                  4  Portuguese     50     0   40     10
# 32                4                  4     Spanish     50     3   20     27
#
#     Estep  Esep  Aquelp
# 1    0.94  0.06    0.00
# 2    1.00  0.00    0.00
# 3    0.96  0.02    0.02
# 4    0.98  0.02    0.00
# 5    0.94  0.06    0.00
# 6    0.98  0.02    0.00
# 7    0.96  0.04    0.00
# 8    0.98  0.00    0.02
# 9    0.22  0.46    0.32
# 10   0.18  0.82    0.00
# 11   0.18  0.80    0.02
# 12   0.32  0.68    0.00
# 13   0.36  0.48    0.16
# 14   0.34  0.66    0.00
# 15   0.42  0.30    0.28
# 16   0.30  0.68    0.02
# 17   0.00  0.10    0.90
# 18   0.02  0.48    0.50
# 19   0.00  0.34    0.66
# 20   0.00  0.80    0.20
# 21   0.02  0.86    0.12
# 22   0.00  0.88    0.12
# 23   0.04  0.70    0.26
# 24   0.00  0.82    0.18
# 25   0.00  0.02    0.98
# 26   0.00  0.02    0.98
# 27   0.00  0.04    0.96
# 28   0.00  0.06    0.94
# 29   0.00  0.20    0.80
# 30   0.00  0.24    0.76
# 31   0.00  0.80    0.20
# 32   0.06  0.40    0.54

# %% [markdown]
# ## Grid approximation
#
# Let's start simple by doing a grid approximation, where we divide the continuous 2D space of possible parameter settings up into a discrete space. For example, let's start with all possible combinations of $\theta_{1}$ and $\theta_{2}$ from 0.1 to 0.6, in steps of 0.05.
#
# Let's first load in the model predictions of the RSA model for this discrete grid space:

# %%
model_predictions = pd.read_csv('model_predictions/HigherSearchD_MW_RSA_tau_start_0.1_tau_stop_0.61_tau_step_0.05.csv')  

model_predictions
# Out:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 0      distance   este         1.00         0            0             0
# 1      distance  aquel         0.00         0            0             0
# 2      distance   este         1.00         0            0             0
# 3      distance    ese         0.00         0            0             0
# 4      distance  aquel         0.00         0            0             0
# ...         ...    ...          ...       ...          ...           ...
# 29035  pdhybrid   este         0.17         3            0             3
# 29036  pdhybrid  aquel         0.83         3            0             3
# 29037  pdhybrid   este         0.05         3            0             3
# 29038  pdhybrid    ese         0.40         3            0             3
# 29039  pdhybrid  aquel         0.55         3            0             3
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 0                 0       2         0.1          0.1
# 1                 0       2         0.1          0.1
# 2                 0       3         0.1          0.1
# 3                 0       3         0.1          0.1
# 4                 0       3         0.1          0.1
# ...             ...     ...         ...          ...
# 29035             0       2         0.6          0.6
# 29036             0       2         0.6          0.6
# 29037             0       3         0.6          0.6
# 29038             0       3         0.6          0.6
# 29039             0       3         0.6          0.6
#
# [29040 rows x 10 columns]

# %% [markdown]
# For each combination of $\theta_{1}$ (=SpeakerTau) and $\theta_{2}$ (=ListenerTau), this model prediction dataframe provides the probability of producing each of the possible words (_este_ and _aquel_ in the case of the two-system model, _este_, _ese_ and _aquel_ in the case of the three-system model).
#
# For example, to get the probability of producing _este_ under the **distance** model, with $\theta_{1} = 0.6$ and $\theta_{2} = 0.6$, given a 2-word system, when the Referent = 3, and the Listener's position = 3, we'd do the following:

# %%
relevant_row = model_predictions[model_predictions["Model"]=="distance"][model_predictions["Word"]=="este"][model_predictions["Referent"]==0][model_predictions["Listener_pos"]==0][model_predictions["WordNo"]==2][model_predictions["SpeakerTau"]==0.1][model_predictions["ListenerTau"]==0.1]

relevant_row
# Out:
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 0  distance  este          1.0         0            0             0
#
#    Listener_att  WordNo  SpeakerTau  ListenerTau
# 0             0       2         0.1          0.1

# %% [markdown]
# And to now get only the probability value, we'd do:

# %%
prob_of_este = relevant_row["Probability"]

prob_of_este
# Out:
# 0    1.0
# Name: Probability, dtype: float64

# %% [markdown]
# Now, say we want to calculate the likelihood of the combination SpeakerTau = 0.1 + ListenerTau = 0.1, given the data of a particular language. What we have is: For each situation in the experiment (i.e. Referent and Listener position), and for each word (_este_ and _aquel_ in the case of a 2-word language, _este_, _ese_ and _aquel_ in the case of a 3-word language), we have two values:
# 1. The probability of that word being produced according to the model predictions
# 2. The proportion of that word actually being used in that situation by the participants in the experiment
#
# <span class="mark">**Q: How do we calculate $f(x_{i} | \theta_{1}, \theta_{2})$?**</span>
#
# Do we simply treat the model prediction probability as the parameter of a binomial distribution, and we just take the pmf or pdf of the observed count given this binomial distribution?
#
#
# <span class="mark">**Q: Can we treat each word choice independently? As a binomial process where we either choose the word (= 1) or not (= 0)? Regardless of whether we have a 2-word system or a 3-word system?**</span>
#
#
# <span class="mark">**Q: Are our obervations $x_{1}, ..., x_{i}$ independent?**</span>
#
# That is: In the experiment, does each participant just get to see each situation once, and choose a word to produce? Such that the count of _este_ uses in a given situation is not dependent on the count of _aquel_ uses in that same situation?
#
# To get the relevant counts from the data, for English for example, we'd have to do the following:

# %%
relevant_counts_row = data_exp_1_two_system[data_exp_1_two_system["Object_Position"] == 1][data_exp_1_two_system["Listener_Position"] == 1][data_exp_1_two_system["Language"] == "English"]

relevant_counts_row
# Out:
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 1                1                  1  English     51    46      5  0.901961
#
#      Aquelp
# 1  0.098039

# %%
este_count = relevant_counts_row["este"]

este_count
# Out:
# 1    46
# Name: este, dtype: int64

# %%
import numpy as np
from scipy.stats import binom, multinomial

def calc_multinom_pmf(pd_model_predictions, pd_data, model, language, object_pos, listener_pos, speaker_tau, listener_tau):
    if language == "English" or language == "Italian":
        WordNo = 2
        words = ["este", "aquel"]
    elif language == "Portuguese" or language == "Spanish":
        WordNo = 3
        words = ["este", "ese", "aquel"]
    probs_per_word = np.zeros((WordNo))   
    counts_per_word = np.zeros((WordNo))
    for i in range(len(words)):
        word = words[i]
        print('')
        print("word is:")
        print(word)
        model_prediction_row = pd_model_predictions[model_predictions["Model"]==model][model_predictions["Word"]==word][model_predictions["Referent"]==object_pos][model_predictions["Listener_pos"]==listener_pos][model_predictions["WordNo"]==WordNo][model_predictions["SpeakerTau"]==speaker_tau][model_predictions["ListenerTau"]==listener_tau]
        print("model_prediction_row is:")
        print(model_prediction_row)
        model_prediction_prob = model_prediction_row["Probability"]
        print("model_prediction_prob is:")
        print(model_prediction_prob)
        probs_per_word[i] = model_prediction_prob
        # Below is object_pos+1 and listener_pos+1, because in the model_predictions dataframe it starts counting 
        # from 0, but in the experimental data dataframe it starts counting from 1.
        data_count_row = pd_data[data_exp_1_two_system["Object_Position"] == object_pos+1][data_exp_1_two_system["Listener_Position"] == listener_pos+1][data_exp_1_two_system["Language"] == language]
        print('')
        print("data_count_row is:")
        print(data_count_row)
        data_count = data_count_row[word]
        print("data_count is:")
        print(data_count)
        counts_per_word[i] = data_count
        total = data_count_row["Total"]
        print("total is:")
        print(total)
    multinom_pmf = multinomial.pmf(counts_per_word, n=total, p=probs_per_word)
    multinom_logpmf = multinomial.logpmf(counts_per_word, n=total, p=probs_per_word)
    return multinom_pmf, multinom_logpmf


multinom_pmf, multinom_logpmf = calc_multinom_pmf(model_predictions, data_exp_1_two_system, "distance", "English", 1, 0, 0.4, 0.4)
print('')
print('')
print("multinom_pmf is:")
print(multinom_pmf)
print('')
print("multinom_logpmf is:")
print(multinom_logpmf)
# Out:
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17285  distance  este         0.94         1            0             0
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17285             0       2         0.4          0.4
# model_prediction_prob is:
# 17285    0.94
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 9                2                  1  English     51    25     26  0.490196
#
#      Aquelp
# 9  0.509804
# data_count is:
# 9    25
# Name: este, dtype: int64
# total is:
# 9    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17286  distance  aquel         0.06         1            0             0
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17286             0       2         0.4          0.4
# model_prediction_prob is:
# 17286    0.06
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 9                2                  1  English     51    25     26  0.490196
#
#      Aquelp
# 9  0.509804
# data_count is:
# 9    26
# Name: aquel, dtype: int64
# total is:
# 9    51
# Name: Total, dtype: int64
#
#
# multinom_pmf is:
# [9.00552825e-19]
#
# multinom_logpmf is:
# [-41.55127813]
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
model = "distance"  # can be set to either "distance" or "person"
language = "English"  # can be set to "English", "Italian", "Portuguese" or "Spanish"
object_positions = [0, 1, 2, 3]  # array of all possible object (= referent) positions
listener_positions = [0, 1, 2, 3]  # array of all possible listener positions
speaker_tau = 0.4
listener_tau = 0.4

def product_logpmf_over_situations(object_positions, listener_positions, pd_model_predictions, pd_data, model, language, speaker_tau, listener_tau):
    logproduct = np.log(1.0)  # The first probability should be multiplied with 1.0, which is equivalent to 0.0 in log-space
    for object_pos in object_positions:
        print('')
        print('')
        print("object_pos is:")
        print(object_pos)
        for listener_pos in listener_positions:
            print('')
            print("listener_pos is:")
            print(listener_pos)
            multinom_pmf, multinom_logpmf = calc_multinom_pmf(pd_model_predictions, pd_data, model, language, object_pos, listener_pos, speaker_tau, listener_tau)
            print("multinom_pmf is:")
            print(multinom_pmf)
            print("multinom_logpmf is:")
            print(multinom_logpmf)
            print("np.exp(multinom_logpmf) is:")
            print(np.exp(multinom_logpmf))
            logproduct += multinom_logpmf  # multiplication in probability space is equivalent to addition in log-space
    return logproduct
            
    
logproduct = product_logpmf_over_situations(object_positions, listener_positions, model_predictions, data_exp_1_two_system, model, language, speaker_tau, listener_tau)
print('')
print('')
print("logproduct is:")
print(logproduct)
print("np.exp(logproduct) is:")
print(np.exp(logproduct))
# Out:
# object_pos is:
# 0
#
# listener_pos is:
# 0
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17280  distance  este          1.0         0            0             0
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17280             0       2         0.4          0.4
# model_prediction_prob is:
# 17280    1.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 1                1                  1  English     51    46      5  0.901961
#
#      Aquelp
# 1  0.098039
# data_count is:
# 1    46
# Name: este, dtype: int64
# total is:
# 1    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17281  distance  aquel          0.0         0            0             0
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17281             0       2         0.4          0.4
# model_prediction_prob is:
# 17281    0.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 1                1                  1  English     51    46      5  0.901961
#
#      Aquelp
# 1  0.098039
# data_count is:
# 1    5
# Name: aquel, dtype: int64
# total is:
# 1    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [0.]
# multinom_logpmf is:
# [-inf]
# np.exp(multinom_logpmf) is:
# [0.]
#
# listener_pos is:
# 1
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17300  distance  este          1.0         0            0             1
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17300             0       2         0.4          0.4
# model_prediction_prob is:
# 17300    1.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 3                1                  2  English     51    46      5  0.901961
#
#      Aquelp
# 3  0.098039
# data_count is:
# 3    46
# Name: este, dtype: int64
# total is:
# 3    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17301  distance  aquel          0.0         0            0             1
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17301             0       2         0.4          0.4
# model_prediction_prob is:
# 17301    0.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 3                1                  2  English     51    46      5  0.901961
#
#      Aquelp
# 3  0.098039
# data_count is:
# 3    5
# Name: aquel, dtype: int64
# total is:
# 3    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [0.]
# multinom_logpmf is:
# [-inf]
# np.exp(multinom_logpmf) is:
# [0.]
#
# listener_pos is:
# 2
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17320  distance  este          1.0         0            0             2
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17320             0       2         0.4          0.4
# model_prediction_prob is:
# 17320    1.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 5                1                  3  English     51    42      9  0.823529
#
#      Aquelp
# 5  0.176471
# data_count is:
# 5    42
# Name: este, dtype: int64
# total is:
# 5    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17321  distance  aquel          0.0         0            0             2
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17321             0       2         0.4          0.4
# model_prediction_prob is:
# 17321    0.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 5                1                  3  English     51    42      9  0.823529
#
#      Aquelp
# 5  0.176471
# data_count is:
# 5    9
# Name: aquel, dtype: int64
# total is:
# 5    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [0.]
# multinom_logpmf is:
# [-inf]
# np.exp(multinom_logpmf) is:
# [0.]
#
# listener_pos is:
# 3
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17340  distance  este          1.0         0            0             3
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17340             0       2         0.4          0.4
# model_prediction_prob is:
# 17340    1.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 7                1                  4  English     51    47      4  0.921569
#
#      Aquelp
# 7  0.078431
# data_count is:
# 7    47
# Name: este, dtype: int64
# total is:
# 7    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17341  distance  aquel          0.0         0            0             3
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17341             0       2         0.4          0.4
# model_prediction_prob is:
# 17341    0.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 7                1                  4  English     51    47      4  0.921569
#
#      Aquelp
# 7  0.078431
# data_count is:
# 7    4
# Name: aquel, dtype: int64
# total is:
# 7    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [0.]
# multinom_logpmf is:
# [-inf]
# np.exp(multinom_logpmf) is:
# [0.]
#
#
# object_pos is:
# 1
#
# listener_pos is:
# 0
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17285  distance  este         0.94         1            0             0
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17285             0       2         0.4          0.4
# model_prediction_prob is:
# 17285    0.94
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 9                2                  1  English     51    25     26  0.490196
#
#      Aquelp
# 9  0.509804
# data_count is:
# 9    25
# Name: este, dtype: int64
# total is:
# 9    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17286  distance  aquel         0.06         1            0             0
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17286             0       2         0.4          0.4
# model_prediction_prob is:
# 17286    0.06
# Name: Probability, dtype: float64
#
# data_count_row is:
#    Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 9                2                  1  English     51    25     26  0.490196
#
#      Aquelp
# 9  0.509804
# data_count is:
# 9    26
# Name: aquel, dtype: int64
# total is:
# 9    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [9.00552825e-19]
# multinom_logpmf is:
# [-41.55127813]
# np.exp(multinom_logpmf) is:
# [9.00552825e-19]
#
# listener_pos is:
# 1
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17305  distance  este         0.91         1            0             1
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17305             0       2         0.4          0.4
# model_prediction_prob is:
# 17305    0.91
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 11                2                  2  English     51    29     22  0.568627
#
#       Aquelp
# 11  0.431373
# data_count is:
# 11    29
# Name: este, dtype: int64
# total is:
# 11    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17306  distance  aquel         0.09         1            0             1
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17306             0       2         0.4          0.4
# model_prediction_prob is:
# 17306    0.09
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 11                2                  2  English     51    29     22  0.568627
#
#       Aquelp
# 11  0.431373
# data_count is:
# 11    22
# Name: aquel, dtype: int64
# total is:
# 11    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [9.97413451e-11]
# multinom_logpmf is:
# [-23.02844083]
# np.exp(multinom_logpmf) is:
# [9.97413451e-11]
#
# listener_pos is:
# 2
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17325  distance  este         0.94         1            0             2
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17325             0       2         0.4          0.4
# model_prediction_prob is:
# 17325    0.94
# Name: Probability, dtype: float64
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 13                2                  3  English     51    30     21  0.588235
#
#       Aquelp
# 13  0.411765
# data_count is:
# 13    30
# Name: este, dtype: int64
# total is:
# 13    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17326  distance  aquel         0.06         1            0             2
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17326             0       2         0.4          0.4
# model_prediction_prob is:
# 17326    0.06
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 13                2                  3  English     51    30     21  0.588235
#
#       Aquelp
# 13  0.411765
# data_count is:
# 13    21
# Name: aquel, dtype: int64
# total is:
# 13    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [3.92331274e-13]
# multinom_logpmf is:
# [-28.56666983]
# np.exp(multinom_logpmf) is:
# [3.92331274e-13]
#
# listener_pos is:
# 3
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17345  distance  este         0.95         1            0             3
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17345             0       2         0.4          0.4
# model_prediction_prob is:
# 17345    0.95
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 15                2                  4  English     51    32     19  0.627451
#
#       Aquelp
# 15  0.372549
# data_count is:
# 15    32
# Name: este, dtype: int64
# total is:
# 15    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17346  distance  aquel         0.05         1            0             3
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17346             0       2         0.4          0.4
# model_prediction_prob is:
# 17346    0.05
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 15                2                  4  English     51    32     19  0.627451
#
#       Aquelp
# 15  0.372549
# data_count is:
# 15    19
# Name: aquel, dtype: int64
# total is:
# 15    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [1.79045798e-12]
# multinom_logpmf is:
# [-27.04854968]
# np.exp(multinom_logpmf) is:
# [1.79045798e-12]
#
#
# object_pos is:
# 2
#
# listener_pos is:
# 0
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17290  distance  este         0.11         2            0             0
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17290             0       2         0.4          0.4
# model_prediction_prob is:
# 17290    0.11
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 17                3                  1  English     51     8     43  0.156863
#
#       Aquelp
# 17  0.843137
# data_count is:
# 17    8
# Name: este, dtype: int64
# total is:
# 17    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17291  distance  aquel         0.89         2            0             0
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17291             0       2         0.4          0.4
# model_prediction_prob is:
# 17291    0.89
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 17                3                  1  English     51     8     43  0.156863
#
#       Aquelp
# 17  0.843137
# data_count is:
# 17    43
# Name: aquel, dtype: int64
# total is:
# 17    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [0.0909682]
# multinom_logpmf is:
# [-2.39724524]
# np.exp(multinom_logpmf) is:
# [0.0909682]
#
# listener_pos is:
# 1
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17310  distance  este         0.06         2            0             1
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17310             0       2         0.4          0.4
# model_prediction_prob is:
# 17310    0.06
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 19                3                  2  English     51     8     43  0.156863
#
#       Aquelp
# 19  0.843137
# data_count is:
# 19    8
# Name: este, dtype: int64
# total is:
# 19    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17311  distance  aquel         0.94         2            0             1
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17311             0       2         0.4          0.4
# model_prediction_prob is:
# 17311    0.94
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 19                3                  2  English     51     8     43  0.156863
#
#       Aquelp
# 19  0.843137
# data_count is:
# 19    43
# Name: aquel, dtype: int64
# total is:
# 19    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [0.00747628]
# multinom_logpmf is:
# [-4.89601993]
# np.exp(multinom_logpmf) is:
# [0.00747628]
#
# listener_pos is:
# 2
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17330  distance  este         0.06         2            0             2
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17330             0       2         0.4          0.4
# model_prediction_prob is:
# 17330    0.06
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel    Estep  \
# 21                3                  3  English     51    14     37  0.27451
#
#      Aquelp
# 21  0.72549
# data_count is:
# 21    14
# Name: este, dtype: int64
# total is:
# 21    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17331  distance  aquel         0.94         2            0             2
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17331             0       2         0.4          0.4
# model_prediction_prob is:
# 17331    0.94
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel    Estep  \
# 21                3                  3  English     51    14     37  0.27451
#
#      Aquelp
# 21  0.72549
# data_count is:
# 21    37
# Name: aquel, dtype: int64
# total is:
# 21    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [1.0264739e-06]
# multinom_logpmf is:
# [-13.78938103]
# np.exp(multinom_logpmf) is:
# [1.0264739e-06]
#
# listener_pos is:
# 3
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17350  distance  este         0.06         2            0             3
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17350             0       2         0.4          0.4
# model_prediction_prob is:
# 17350    0.06
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 23                3                  4  English     51    15     36  0.294118
#
#       Aquelp
# 23  0.705882
# data_count is:
# 23    15
# Name: este, dtype: int64
# total is:
# 23    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17351  distance  aquel         0.94         2            0             3
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17351             0       2         0.4          0.4
# model_prediction_prob is:
# 17351    0.94
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 23                3                  4  English     51    15     36  0.294118
#
#       Aquelp
# 23  0.705882
# data_count is:
# 23    36
# Name: aquel, dtype: int64
# total is:
# 23    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [1.6161504e-07]
# multinom_logpmf is:
# [-15.63804863]
# np.exp(multinom_logpmf) is:
# [1.6161504e-07]
#
#
# object_pos is:
# 3
#
# listener_pos is:
# 0
#
# word is:
# este
# model_prediction_row is:
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17295  distance  este          0.0         3            0             0
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17295             0       2         0.4          0.4
# model_prediction_prob is:
# 17295    0.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 25                4                  1  English     51    10     41  0.196078
#
#       Aquelp
# 25  0.803922
# data_count is:
# 25    10
# Name: este, dtype: int64
# total is:
# 25    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17296  distance  aquel          1.0         3            0             0
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17296             0       2         0.4          0.4
# model_prediction_prob is:
# 17296    1.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 25                4                  1  English     51    10     41  0.196078
#
#       Aquelp
# 25  0.803922
# data_count is:
# 25    41
# Name: aquel, dtype: int64
# total is:
# 25    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [0.]
# multinom_logpmf is:
# [-inf]
# np.exp(multinom_logpmf) is:
# [0.]
#
# listener_pos is:
# 1
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17315  distance  este          0.0         3            0             1
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17315             0       2         0.4          0.4
# model_prediction_prob is:
# 17315    0.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 27                4                  2  English     51     6     45  0.117647
#
#       Aquelp
# 27  0.882353
# data_count is:
# 27    6
# Name: este, dtype: int64
# total is:
# 27    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17316  distance  aquel          1.0         3            0             1
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17316             0       2         0.4          0.4
# model_prediction_prob is:
# 17316    1.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 27                4                  2  English     51     6     45  0.117647
#
#       Aquelp
# 27  0.882353
# data_count is:
# 27    45
# Name: aquel, dtype: int64
# total is:
# 27    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [0.]
# multinom_logpmf is:
# [-inf]
# np.exp(multinom_logpmf) is:
# [0.]
#
# listener_pos is:
# 2
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17335  distance  este          0.0         3            0             2
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17335             0       2         0.4          0.4
# model_prediction_prob is:
# 17335    0.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 29                4                  3  English     51     7     44  0.137255
#
#       Aquelp
# 29  0.862745
# data_count is:
# 29    7
# Name: este, dtype: int64
# total is:
# 29    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17336  distance  aquel          1.0         3            0             2
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17336             0       2         0.4          0.4
# model_prediction_prob is:
# 17336    1.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 29                4                  3  English     51     7     44  0.137255
#
#       Aquelp
# 29  0.862745
# data_count is:
# 29    44
# Name: aquel, dtype: int64
# total is:
# 29    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [0.]
# multinom_logpmf is:
# [-inf]
# np.exp(multinom_logpmf) is:
# [0.]
#
# listener_pos is:
# 3
#
# word is:
# este
# model_prediction_row is:
#           Model  Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17355  distance  este          0.0         3            0             3
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17355             0       2         0.4          0.4
# model_prediction_prob is:
# 17355    0.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 31                4                  4  English     51    10     41  0.196078
#
#       Aquelp
# 31  0.803922
# data_count is:
# 31    10
# Name: este, dtype: int64
# total is:
# 31    51
# Name: Total, dtype: int64
#
# word is:
# aquel
# model_prediction_row is:
#           Model   Word  Probability  Referent  Speaker_pos  Listener_pos  \
# 17356  distance  aquel          1.0         3            0             3
#
#        Listener_att  WordNo  SpeakerTau  ListenerTau
# 17356             0       2         0.4          0.4
# model_prediction_prob is:
# 17356    1.0
# Name: Probability, dtype: float64
#
# data_count_row is:
#     Object_Position  Listener_Position Language  Total  este  aquel     Estep  \
# 31                4                  4  English     51    10     41  0.196078
#
#       Aquelp
# 31  0.803922
# data_count is:
# 31    41
# Name: aquel, dtype: int64
# total is:
# 31    51
# Name: Total, dtype: int64
# multinom_pmf is:
# [0.]
# multinom_logpmf is:
# [-inf]
# np.exp(multinom_logpmf) is:
# [0.]
#
#
# logproduct is:
# [-inf]
# np.exp(logproduct) is:
# [0.]
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/U968195/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# <span class="mark">**Q: What to do if multinomial pmf = 0.0?**</span>

# %% [markdown]
# ## Monte Carlo

# %% [markdown]
# ## Model Comparison
